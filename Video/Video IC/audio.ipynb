# %%
from IPython.display import Audio

# %%
! edge-tts --voice pt-BR-ThalitaNeural --text "Neste vídeo você irá aprender os conceitos básicos por trás da computação quântica e seus benefícios sobre a computação clássica para resolução de problemas complexos." --write-media 1.mp3
# Out:
# WEBVTT
#
# 00:00:00.100 --> 00:00:03.775
# Neste vídeo você irá aprender os conceitos básicos por trás
#
# 00:00:03.788 --> 00:00:07.888
# da computação quântica e seus benefícios sobre a computação clássica
#
# 00:00:07.900 --> 00:00:10.387
# para resolução de problemas complexos

# %%
def generate_audio(text, filename):
    command = f'! edge-tts --voice pt-BR-ThalitaNeural --text "{text}" --write-media {filename}'
    get_ipython().system(command)
    
    return Audio(filename)

# %%
Audio_file = generate_audio("Neste vídeo você irá aprender os conceitos básicos por trás da computação quântica e seus benefícios sobre a computação clássica para resolução de problemas complexos.", "1.mp3")
Audio_file
# Out:
# WEBVTT
#
# 00:00:00.100 --> 00:00:03.775
# Neste vídeo você irá aprender os conceitos básicos por trás
#
# 00:00:03.788 --> 00:00:07.888
# da computação quântica e seus benefícios sobre a computação clássica
#
# 00:00:07.900 --> 00:00:10.387
# para resolução de problemas complexos
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
