# %%
from IPython.display import Audio
# %cd "Video/Video IC/audio"
# Out:
# /home/gabriel/qiskit/Quantum-Computing/Video/Video IC/audio

# %%
def generate_audio(text, filename, voice='pt-BR-ThalitaNeural'):
    
    command = f'! edge-tts --voice {voice} --text "{text}" --write-media {filename}'
    get_ipython().system(command)
    
    return Audio(filename)

# %%
generate_audio("Neste vídeo você irá aprender os conceitos básicos por trás da computação quântica e seus benefícios sobre a computação clássica para resolução de problemas complexos.", "1.mp3")

# %%
a = "A computação quântica, apesar de funcionalmente diferente da clássica, possui elementos em comum, o que permite traçar algumas comparações entre ambos."


generate_audio(f"{a}", "2.mp3")

# %%
a = "em específico, os bits clássicos, blocos fundamentais da computação clássica, são análogos aos bits quânticos, ou kiubites, que são a base da computação quântica." 

generate_audio(f"{a}", "3.mp3")

# %%
a = "Os bits clássicos são compostos por dois valores. 0 e 1. Por outro lado, os kiubites são representados pelos estados kete 0 e kete 1. Apresentados aqui na notação de Dirac."


generate_audio(f"{a}", "4.mp3")

# %%
a = "Enquanto os bits clássicos podem ocupar dois possíveis valores, os kiubites podem ser representados por uma combinação linear de estados, chamado de superposição."


generate_audio(f"{a}", "5.mp3")

# %%
a = "Sendo assim, os estados quânticos dos kiubites podem ser considerados como um vetor em um espaço vetorial complexo bidimensional, onde os estados kete 0 e kete 1, naturalmente ortogonais, formam a base do espaço vetorial, chamada de base computacional."


generate_audio(f"{a}", "6.mp3")

# %%
a = "Uma das propriedades mais importantes de estados quânticos, é de que não é possível medir o estado psi de um kiubite sem alterá-lo. Isso nos diz que após realizar uma medida de um estado psi de um kiubite, o estado do kiubite será alterado para um dos estados da base computacional, kete 0 ou kete 1. A probabilidade de medir o estado kete 0 é de módulo de alpha ao quadrado, e a probabilidade de medir o estado kete 1 é de módulo de beta ao quadrado. Onde a soma dessas probabilidades tem que ser igual a 1."


generate_audio(f"{a}", "7.mp3")
# Out:
# WEBVTT
#
# 00:00:00.100 --> 00:00:03.962
# Uma das propriedades mais importantes de estados quânticos é de
#
# 00:00:03.975 --> 00:00:06.338
# que não é possível medir o estado psi de um
#
# 00:00:06.350 --> 00:00:10.050
# kiubite sem alterá-lo Isso nos diz que após realizar uma
#
# 00:00:10.062 --> 00:00:12.838
# medida de um estado psi de um kiubite o estado
#
# 00:00:12.850 --> 00:00:16.050
# do kiubite será alterado para um dos estados da base
#
# 00:00:16.062 --> 00:00:20.663
# computacional kete 0 ou kete 1 A probabilidade de medir o
#
# 00:00:20.675 --> 00:00:23.913
# estado kete 0 é de módulo de alpha ao quadrado e
#
# 00:00:23.925 --> 00:00:27.250
# a probabilidade de medir o estado kete 1 é de módulo
#
# 00:00:27.262 --> 00:00:31.050
# de beta ao quadrado Onde a soma dessas probabilidades tem
#
# 00:00:31.062 --> 00:00:32.050
# que ser igual a 1
#                 <audio  controls="controls" >
# ...

# %%
a = "Sendo assim, o estado de um kiubite deve pertencer à circunferencia unitária no plano complexo, de modo a respeitar as probabilidades alpha ao quadrado ou probabilidade de obter 0 e beta ao quadrado ou probabilidade de obter 1."


generate_audio(f"{a}", "8.mp3")

# %% [markdown]
# # Testando outras vozes

# %%
! edge-tts --list-voices
# Out:
# Name: af-ZA-AdriNeural
# Gender: Female
#
# Name: af-ZA-WillemNeural
# Gender: Male
#
# Name: am-ET-AmehaNeural
# Gender: Male
#
# Name: am-ET-MekdesNeural
# Gender: Female
#
# Name: ar-AE-FatimaNeural
# Gender: Female
#
# Name: ar-AE-HamdanNeural
# Gender: Male
#
# Name: ar-BH-AliNeural
# Gender: Male
#
# Name: ar-BH-LailaNeural
# Gender: Female
#
# Name: ar-DZ-AminaNeural
# Gender: Female
#
# Name: ar-DZ-IsmaelNeural
# Gender: Male
#
# Name: ar-EG-SalmaNeural
# Gender: Female
#
# Name: ar-EG-ShakirNeural
# Gender: Male
#
# Name: ar-IQ-BasselNeural
# Gender: Male
#
# Name: ar-IQ-RanaNeural
# Gender: Female
#
# Name: ar-JO-SanaNeural
# Gender: Female
#
# Name: ar-JO-TaimNeural
# Gender: Male
#
# Name: ar-KW-FahedNeural
# Gender: Male
#
# Name: ar-KW-NouraNeural
# Gender: Female
#
# Name: ar-LB-LaylaNeural
# Gender: Female
#
# Name: ar-LB-RamiNeural
# Gender: Male
#
# Name: ar-LY-ImanNeural
# Gender: Female
#
# Name: ar-LY-OmarNeural
# Gender: Male
#
# Name: ar-MA-JamalNeural
# ...

# %%
voices = ["pt-BR-ThalitaNeural", "pt-BR-FranciscaNeural", "pt-BR-AntonioNeural"]

a = "Olá! Hoje vamos explorar o mundo da computação quântica aplicada a materiais."

for voice in voices:
    
    generate_audio(f"{a}", f"audio_1_{voice}.mp3", voice)
# Out:
# WEBVTT
#
# 00:00:00.100 --> 00:00:04.325
# Olá Hoje vamos explorar o mundo da computação quântica aplicada
#
# 00:00:04.338 --> 00:00:05.188
# a materiais
#
# WEBVTT
#
# 00:00:00.100 --> 00:00:04.125
# Olá Hoje vamos explorar o mundo da computação quântica aplicada
#
# 00:00:04.138 --> 00:00:04.938
# a materiais
#
# WEBVTT
#
# 00:00:00.100 --> 00:00:04.575
# Olá Hoje vamos explorar o mundo da computação quântica aplicada
#
# 00:00:04.588 --> 00:00:05.375
# a materiais

# %%
a = "Agora apresentaremos uma notação diistinta para lidar com os estados (Psi) dos kiubites. Como os coeficientes alpha e beta são números complexos, podemos utilizar a forma polar para representálos, dada pela seguinte expressão. Onde z é um número complexo, r é o módulo de z e theta é o argumento de z."

generate_audio(f"{a}", "9.mp3")
# Out:
# WEBVTT
#
# 00:00:00.100 --> 00:00:04.388
# Agora apresentaremos uma notação diistinta para lidar com os estados
#
# 00:00:04.575 --> 00:00:08.562
# Psi dos kiubites Como os coeficientes alpha e beta são
#
# 00:00:08.575 --> 00:00:13.488
# números complexos podemos utilizar a forma polar para representálos dada
#
# 00:00:13.500 --> 00:00:17.350
# pela seguinte expressão Onde z é um número complexo r
#
# 00:00:17.363 --> 00:00:19.650
# é o módulo de z e theta é o argumento
#
# 00:00:19.663 --> 00:00:20.075
# de z
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
a = "Agora apresentaremos uma notação diistinta para lidar com os estados (Psi) dos kiubites. Como os coeficientes alpha e beta são números complexos, podemos utilizar a forma polar para representálos, dada pela seguinte expressão. Onde z é um número complexo, a e b são numeros reais. Ou ainda, utilizando a notação de Êuler, onde r é o módulo de z ,e theta é o argumento de z."

generate_audio(f"{a}", "10.mp3")
# Out:
# WEBVTT
#
# 00:00:00.100 --> 00:00:04.388
# Agora apresentaremos uma notação diistinta para lidar com os estados
#
# 00:00:04.575 --> 00:00:08.562
# Psi dos kiubites Como os coeficientes alpha e beta são
#
# 00:00:08.575 --> 00:00:13.488
# números complexos podemos utilizar a forma polar para representálos dada
#
# 00:00:13.500 --> 00:00:17.200
# pela seguinte expressão Onde z é um número complexo a
#
# 00:00:17.212 --> 00:00:21.025
# e b são numeros reais Ou ainda utilizando a notação
#
# 00:00:21.038 --> 00:00:23.500
# de Êuler onde r é o módulo de z e
#
# 00:00:23.512 --> 00:00:25.025
# theta é o argumento de z
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
a = "Agora, realizando algumas manipulações algébricas, podemos reescrever o estado de um kiubite em termos dos raios e respectivos ângulos theta, apresentando assim um coeficiente global multiplicando a superposição dos estados kete 0 e kete 1, chamado de fase global."

generate_audio(f"{a}", "11.mp3")
# Out:
# WEBVTT
#
# 00:00:00.100 --> 00:00:05.312
# Agora realizando algumas manipulações algébricas podemos reescrever o estado de
#
# 00:00:05.325 --> 00:00:09.113
# um kiubite em termos dos raios e respectivos ângulos theta
#
# 00:00:09.287 --> 00:00:14.225
# apresentando assim um coeficiente global multiplicando a superposição dos estad-
# os
#
# 00:00:14.238 --> 00:00:17.425
# kete 0 e kete 1 chamado de fase global
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
a = "A seguir, vamos provar que a fase global de um kiubite é totalmente irrelevante, dependendo apenas da fase relativa, que corresponde a diferença dos ângulos theta. Sendo assim, introduzimos um novo estado, kete Psi linha, que corresponde ao mesmo estado que kete psi, mas sem a fase global."

generate_audio(f"{a}", "12.mp3")
# Out:
# WEBVTT
#
# 00:00:00.100 --> 00:00:02.850
# A seguir vamos provar que a fase global de um
#
# 00:00:02.862 --> 00:00:07.787
# kiubite é totalmente irrelevante dependendo apenas da fase relativa que
#
# 00:00:07.800 --> 00:00:12.425
# corresponde a diferença dos ângulos theta Sendo assim introduzimos um
#
# 00:00:12.438 --> 00:00:16.087
# novo estado kete Psi linha que corresponde ao mesmo estado
#
# 00:00:16.100 --> 00:00:18.488
# que kete psi mas sem a fase global
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
a = "Agora, para comparar ambos os estados e provar que são totalmente equivalentes, faremos uma análise do valor esperado para um dado operador, que é uma medida de uma propriedade física do sistema. Para isso, utilizaremos um operador genérico, o operador Ó."

generate_audio(f"{a}", "13.mp3")
# Out:
# WEBVTT
#
# 00:00:00.100 --> 00:00:03.400
# Agora para comparar ambos os estados e provar que são
#
# 00:00:03.413 --> 00:00:07.550
# totalmente equivalentes faremos uma análise do valor esperado para um
#
# 00:00:07.562 --> 00:00:11.075
# dado operador que é uma medida de uma propriedade física
#
# 00:00:11.088 --> 00:00:15.925
# do sistema Para isso utilizaremos um operador genérico o operador
#
# 00:00:15.938 --> 00:00:16.125
# Ó
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
a = "Realizando a substituição de kete psi linha por kete psi, multiplicado pela fase global, obtemos que o valor esperado para o operador Ó é o mesmo para ambos os estados, o que nos diz que a fase global de um kiubite é totalmente irrelevante para a computação quântica, dependendo apenas da fase relativa entre alpha e beta, que corresponde a theta 0 e theta 1."

generate_audio(f"{a}", "14.mp3")
# Out:
# WEBVTT
#
# 00:00:00.100 --> 00:00:03.612
# Realizando a substituição de kete psi linha por kete psi
#
# 00:00:03.775 --> 00:00:07.912
# multiplicado pela fase global obtemos que o valor esperado para
#
# 00:00:07.925 --> 00:00:10.787
# o operador Ó é o mesmo para ambos os estados
#
# 00:00:11.088 --> 00:00:13.100
# o que nos diz que a fase global de um
#
# 00:00:13.113 --> 00:00:17.950
# kiubite é totalmente irrelevante para a computação quântica dependendo apenas
#
# 00:00:17.962 --> 00:00:21.525
# da fase relativa entre alpha e beta que corresponde a
#
# 00:00:21.538 --> 00:00:22.988
# theta 0 e theta 1
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
a = "Sendo assim, de agora em diante vamos ignorar a fase global dos kiubites, focando apenas na fase relativa entre os estados kete 0 e kete 1. Além disso, vamos determinar uma nova notação para a fase relativa, délta, que corresponde a essa diferença de fases."

generate_audio(f"{a}", "15.mp3")
# Out:
# WEBVTT
#
# 00:00:00.100 --> 00:00:03.312
# Sendo assim de agora em diante vamos ignorar a fase
#
# 00:00:03.325 --> 00:00:07.013
# global dos kiubites focando apenas na fase relativa entre os
#
# 00:00:07.025 --> 00:00:11.463
# estados kete 0 e kete 1 Além disso vamos determinar uma
#
# 00:00:11.475 --> 00:00:15.488
# nova notação para a fase relativa délta que corresponde a
#
# 00:00:15.500 --> 00:00:17.100
# essa diferença de fases
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
a = "Portanto, esse é o novo estado obtido para representar psi. Assim como na superposição original utilizando alpha e beta, aqui, r 0 e r 1 Ê elevado a i delta são coeficientes complexos que representam as probabilidades, e portanto, sua soma ao quadrado deve ser igual a 1."

generate_audio(f"{a}", "16.mp3")
# Out:
# WEBVTT
#
# 00:00:00.100 --> 00:00:03.788
# Portanto esse é o novo estado obtido para representar psi
#
# 00:00:04.050 --> 00:00:08.400
# Assim como na superposição original utilizando alpha e beta aqui
#
# 00:00:08.550 --> 00:00:12.088
# r 0 e r 1 Ê elevado a i delta são coeficientes
#
# 00:00:12.100 --> 00:00:16.700
# complexos que representam as probabilidades e portanto sua soma ao
#
# 00:00:16.712 --> 00:00:18.512
# quadrado deve ser igual a 1
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
a = "Utilizando o fato de que este último termo é um número complexo, por definição. podemos reescrevêlo utilizando x e y reais. Realizando a substituição e simplificando a expressão, obtemos a seguinte expressão, que representa a equação de uma esfera centrada na origem de raio igual a 1."

generate_audio(f"{a}", "17.mp3")
# Out:
# WEBVTT
#
# 00:00:00.100 --> 00:00:02.837
# Utilizando o fato de que este último termo é um
#
# 00:00:02.850 --> 00:00:08.175
# número complexo por definição podemos reescrevêlo utilizando x e y
#
# 00:00:08.188 --> 00:00:13.088
# reais Realizando a substituição e simplificando a expressão obtemos a
#
# 00:00:13.100 --> 00:00:17.038
# seguinte expressão que representa a equação de uma esfera centrada
#
# 00:00:17.050 --> 00:00:18.988
# na origem de raio igual a 1
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
a = "Onde podemos finalmente substituir a variável r 0 por z, apenas para simplificar a notação. Sendo assim, essa equação representa a condição de normalização que devemos seguir para que o estado do kiubite seja válido. Como a equação obtida é a de uma esfera, sabemos que o espaço que o estado do kiubite pode ocupar é uma esfera unitária no espaço vetorial complexo, chamada de esfera de Bloch."

generate_audio(f"{a}", "18.mp3")
# Out:
# WEBVTT
#
# 00:00:00.100 --> 00:00:04.800
# Onde podemos finalmente substituir a variável r 0 por z apenas
#
# 00:00:04.812 --> 00:00:09.213
# para simplificar a notação Sendo assim essa equação representa a
#
# 00:00:09.225 --> 00:00:12.738
# condição de normalização que devemos seguir para que o estado
#
# 00:00:12.750 --> 00:00:16.125
# do kiubite seja válido Como a equação obtida é a
#
# 00:00:16.137 --> 00:00:18.913
# de uma esfera sabemos que o espaço que o estado
#
# 00:00:18.925 --> 00:00:22.150
# do kiubite pode ocupar é uma esfera unitária no espaço
#
# 00:00:22.163 --> 00:00:25.363
# vetorial complexo chamada de esfera de Bloch
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
a = "Para realizar a análise da esfera de Bloch, primeiro iremos realizar uma mudança de coordenadas, deixando de utilizar as coordenadas cartesianas x, y e z, e passaremos a utilizar as coordenadas esféricas, r, theta e phi. Onde theta é o ângulo polar e phi é o ângulo azimutal e r é o raio da esfera, que é igual a 1."

generate_audio(f"{a}", "19.mp3")
# Out:
# WEBVTT
#
# 00:00:00.100 --> 00:00:03.550
# Para realizar a análise da esfera de Bloch primeiro iremos
#
# 00:00:03.562 --> 00:00:07.875
# realizar uma mudança de coordenadas deixando de utilizar as coordenadas
#
# 00:00:07.888 --> 00:00:12.025
# cartesianas x y e z e passaremos a utilizar as
#
# 00:00:12.037 --> 00:00:16.062
# coordenadas esféricas r theta e phi Onde theta é o
#
# 00:00:16.075 --> 00:00:18.863
# ângulo polar e phi é o ângulo azimutal e r
#
# 00:00:18.875 --> 00:00:21.012
# é o raio da esfera que é igual a 1
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
a = "Realizando as respectivas substituições, obtemos a seguinte expressão final. Esta espressão, assim como a expressão original para o estado psi, que utiliza alpha e beta, pode representar um estado genérico qualquer de um kiubite. Porém, diferentemente da expressão original que representa um estado em um espaço vetorial complexo bidimensional, esta expressão representa um estado em um espaço vetorial complexo tridimensional. E a area que o estado do kiubite pode ocupar já não é mais uma circunferencia unitária, mas sim uma esfera. a esfera de Bloch."

generate_audio(f"{a}", "20.mp3")
# Out:
# WEBVTT
#
# 00:00:00.100 --> 00:00:05.650
# Realizando as respectivas substituições obtemos a seguinte expressão final Esta
#
# 00:00:05.662 --> 00:00:09.312
# espressão assim como a expressão original para o estado psi
#
# 00:00:09.450 --> 00:00:13.238
# que utiliza alpha e beta pode representar um estado genérico
#
# 00:00:13.250 --> 00:00:17.825
# qualquer de um kiubite Porém diferentemente da expressão original que
#
# 00:00:17.837 --> 00:00:22.600
# representa um estado em um espaço vetorial complexo bidimensional esta
#
# 00:00:22.613 --> 00:00:27.450
# expressão representa um estado em um espaço vetorial complexo tridimensional
#
# 00:00:27.712 --> 00:00:30.363
# E a area que o estado do kiubite pode ocupar
#
# 00:00:30.375 --> 00:00:33.612
# já não é mais uma circunferencia unitária mas sim uma
#
# 00:00:33.625 --> 00:00:35.612
# esfera a esfera de Bloch
#                 <audio  controls="controls" >
# ...

# %%
a = "O seguinte estado apresentado é chamado de estado kete mais, e corresponde a uma superposição que possui uma probabilidade de 50 por cento de medir o estado kete 0 e 50 por cento de medir o estado kete 1. Sendo assim, esse estado é representado na esfera de Bloch no ponto localizado entre os estados da base computacional, indicando uma probabilidade de colapso igual para ambos os estados."

generate_audio(f"{a}", "21.mp3")
# Out:
# WEBVTT
#
# 00:00:00.100 --> 00:00:03.600
# O seguinte estado apresentado é chamado de estado kete mais
#
# 00:00:03.850 --> 00:00:07.662
# e corresponde a uma superposição que possui uma probabilidade de
#
# 00:00:07.675 --> 00:00:11.938
# 50 por cento de medir o estado kete 0 e 50 por cento
#
# 00:00:11.950 --> 00:00:15.450
# de medir o estado kete 1 Sendo assim esse estado
#
# 00:00:15.463 --> 00:00:19.087
# é representado na esfera de Bloch no ponto localizado entre
#
# 00:00:19.100 --> 00:00:23.962
# os estados da base computacional indicando uma probabilidade de colapso
#
# 00:00:23.975 --> 00:00:25.812
# igual para ambos os estados
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
a = "Uma simples mudança de fase no estado kete mais, resulta no estado kete menos, que possui a mesma probabilidade de medir o estado kete 0 e kete 1, porém com uma diferença de fase, que corresponde ao sinal negativo no segundo termo. Este estado ainda é representado como estando no equador da esfera de Bloch, porém em um ponto diametralmente oposto ao estado kete mais, devido a diferença de fase. Ainda que esta diferença de fase não tenha impacto na medição do estado, ela é um parametro importante utilizado para realizar operações quânticas."

generate_audio(f"{a}", "22.mp3")
# Out:
# WEBVTT
#
# 00:00:00.100 --> 00:00:03.888
# Uma simples mudança de fase no estado kete mais resulta
#
# 00:00:03.900 --> 00:00:07.450
# no estado kete menos que possui a mesma probabilidade de
#
# 00:00:07.463 --> 00:00:10.738
# medir o estado kete 0 e kete 1 porém com uma
#
# 00:00:10.750 --> 00:00:14.650
# diferença de fase que corresponde ao sinal negativo no segundo
#
# 00:00:14.662 --> 00:00:18.525
# termo Este estado ainda é representado como estando no equador
#
# 00:00:18.538 --> 00:00:22.137
# da esfera de Bloch porém em um ponto diametralmente oposto
#
# 00:00:22.150 --> 00:00:25.850
# ao estado kete mais devido a diferença de fase Ainda
#
# 00:00:25.863 --> 00:00:29.012
# que esta diferença de fase não tenha impacto na medição
#
# 00:00:29.025 --> 00:00:32.850
# do estado ela é um parametro importante utilizado para realizar
#
# 00:00:32.862 --> 00:00:34.225
# operações quânticas
#                 <audio  controls="controls" >
# ...

# %%
a = "O VQE, ou Variashional Quantum Eigênsólver é um método que vem do teorema variacional, que consiste em achar o estado fundamental de um sistema através de um chute e otimização dos parâmetros desse chute inicial."

generate_audio(f"{a}", "23.mp3")
# Out:
# WEBVTT
#
# 00:00:00.100 --> 00:00:04.138
# O VQE ou Variashional Quantum Eigênsólver é um método que
#
# 00:00:04.150 --> 00:00:07.862
# vem do teorema variacional que consiste em achar o estado
#
# 00:00:07.875 --> 00:00:11.500
# fundamental de um sistema através de um chute e otimização
#
# 00:00:11.512 --> 00:00:13.762
# dos parâmetros desse chute inicial
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
a = "Suponha um Psi que depende de alpha para otimizarmos esse sistema. Chegando ao mínimo, precisamos derivar e igualar a zero e obter o valor de alpha. Depois utilizamos esse valor de alpha no nosso Psi inicial. Assim teremos uma aproximação melhor do sistema."

generate_audio(f"{a}", "24.mp3")
# Out:
# WEBVTT
#
# 00:00:00.100 --> 00:00:03.487
# Suponha um Psi que depende de alpha para otimizarmos esse
#
# 00:00:03.500 --> 00:00:07.925
# sistema Chegando ao mínimo precisamos derivar e igualar a zero
#
# 00:00:07.938 --> 00:00:11.512
# e obter o valor de alpha Depois utilizamos esse valor
#
# 00:00:11.525 --> 00:00:15.425
# de alpha no nosso Psi inicial Assim teremos uma aproximação
#
# 00:00:15.438 --> 00:00:16.562
# melhor do sistema
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
a = "Esse é o procedimento básico de como funciona o método variacional."

generate_audio(f"{a}", "25.mp3")
# Out:
# WEBVTT
#
# 00:00:00.100 --> 00:00:03.450
# Esse é o procedimento básico de como funciona o método
#
# 00:00:03.462 --> 00:00:04.325
# variacional
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
a = "Agora, com ele e um computador quântico, podemos fazer simulações para encontrar o estado fundamental, por exemplo, do hidrogênio."

generate_audio(f"{a}", "26.mp3")
# Out:
# WEBVTT
#
# 00:00:00.100 --> 00:00:04.350
# Agora com ele e um computador quântico podemos fazer simulações
#
# 00:00:04.362 --> 00:00:08.425
# para encontrar o estado fundamental por exemplo do hidrogênio
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
a = "O que o VQÉ irá fazer é, dado um chute para o estado inicial, ele aplicará o teorema variacional, irá calcular o alpha e depois utilizar esse valor para criar um novo sistema otimizado. Ele fará o processo quantas vezes for necessário, até chegar em um mínimo onde os ganhos de otimização são muito poucos."

generate_audio(f"{a}", "27.mp3")
# Out:
# WEBVTT
#
# 00:00:00.100 --> 00:00:02.688
# O que o VQÉ irá fazer é dado um chute
#
# 00:00:02.700 --> 00:00:06.625
# para o estado inicial ele aplicará o teorema variacional irá
#
# 00:00:06.638 --> 00:00:10.050
# calcular o alpha e depois utilizar esse valor para criar
#
# 00:00:10.062 --> 00:00:14.075
# um novo sistema otimizado Ele fará o processo quantas vezes
#
# 00:00:14.088 --> 00:00:17.225
# for necessário até chegar em um mínimo onde os ganhos
#
# 00:00:17.238 --> 00:00:19.363
# de otimização são muito poucos
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
a = "O processo de otimização é feito classicamente e pode ser feito com otimizadores diferentes, devemos nos atentar a isso e escolher o otimizador que melhor lida com nossos problemas e cálculos."

generate_audio(f"{a}", "28.mp3")
# Out:
# WEBVTT
#
# 00:00:00.100 --> 00:00:03.587
# O processo de otimização é feito classicamente e pode ser
#
# 00:00:03.600 --> 00:00:07.862
# feito com otimizadores diferentes devemos nos atentar a isso e
#
# 00:00:07.875 --> 00:00:11.363
# escolher o otimizador que melhor lida com nossos problemas e
#
# 00:00:11.375 --> 00:00:12.062
# cálculos
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
a = "A parte quântica do processo vem da criação dos estados e suas medições, para de fato termos a confirmação de um estado fundamental."

generate_audio(f"{a}", "29.mp3")
# Out:
# WEBVTT
#
# 00:00:00.100 --> 00:00:03.300
# A parte quântica do processo vem da criação dos estados
#
# 00:00:03.312 --> 00:00:06.675
# e suas medições para de fato termos a confirmação de
#
# 00:00:06.688 --> 00:00:08.050
# um estado fundamental
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
a = "Agora que os conceitos básicos foram apresentados, vamos agora demonstrar "

generate_audio(f"{a}", "30.mp3")

# %%
a = "Utilizando alguns artificios matematicos, é possível expressar essa mesma forma de um kiubite utilizando coordenadas polares, de forma que a expressão é "

generate_audio(f"{a}", "31.mp3")
