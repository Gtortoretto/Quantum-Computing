# %%
from IPython.display import Audio
# %cd "Video/Video IC/audio"
# Out:
# /home/gabriel/qiskit/Quantum-Computing/Video/Video IC/audio

# %%
def generate_audio(text, filename):
    
    command = f'! edge-tts --voice pt-BR-ThalitaNeural --text "{text}" --write-media {filename}'
    get_ipython().system(command)
    
    return Audio(filename)

# %%
generate_audio("Neste vídeo você irá aprender os conceitos básicos por trás da computação quântica e seus benefícios sobre a computação clássica para resolução de problemas complexos.", "1.mp3")
# Out:
# WEBVTT
#
# 00:00:00.100 --> 00:00:03.775
# Neste vídeo você irá aprender os conceitos básicos por trás
#
# 00:00:03.788 --> 00:00:07.888
# da computação quântica e seus benefícios sobre a computação clássica
#
# 00:00:07.900 --> 00:00:10.387
# para resolução de problemas complexos
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
a = "A computação quântica, apesar de funcionalmente diferente da clássica, possui elementos em comum, o que permite traçar algumas comparações entre ambos."


generate_audio(f"{a}", "2.mp3")
# Out:
# WEBVTT
#
# 00:00:00.100 --> 00:00:05.025
# A computação quântica apesar de funcionalmente diferente da clássica possui
#
# 00:00:05.037 --> 00:00:08.988
# elementos em comum o que permite traçar algumas comparações entre
#
# 00:00:09.000 --> 00:00:09.450
# ambos
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
a = "em específico, os bits clássicos, blocos fundamentais da computação clássica, são análogos aos bits quânticos, ou kiubites, que são a base da computação quântica." 

generate_audio(f"{a}", "3.mp3")
# Out:
# WEBVTT
#
# 00:00:00.100 --> 00:00:05.487
# em específico os bits clássicos blocos fundamentais da computação clássica
#
# 00:00:05.638 --> 00:00:09.150
# são análogos aos bits quânticos ou kiubites que são a
#
# 00:00:09.162 --> 00:00:11.025
# base da computação quântica
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
a = "Os bits clássicos são compostos por dois valores. 0 e 1. Por outro lado, os kiubites são representados pelos estados kete 0 e kete 1. Apresentados aqui na notação de Dirac."


generate_audio(f"{a}", "4.mp3")
# Out:
# WEBVTT
#
# 00:00:00.100 --> 00:00:04.562
# Os bits clássicos são compostos por dois valores 0 e 1
#
# 00:00:04.825 --> 00:00:08.925
# Por outro lado os kiubites são representados pelos estados kete
#
# 00:00:08.938 --> 00:00:12.850
# 0 e kete 1 apresentados aqui na notação de Dirac
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
a = "Enquanto os bits clássicos podem ocupar dois possíveis valores, os kiubites podem ser representados por uma combinação linear de estados, chamado de superposição."


generate_audio(f"{a}", "5.mp3")
# Out:
# WEBVTT
#
# 00:00:00.100 --> 00:00:04.425
# Enquanto os bits clássicos podem ocupar dois possíveis valores os
#
# 00:00:04.438 --> 00:00:08.725
# kiubites podem ser representados por uma combinação linear de estados
#
# 00:00:08.863 --> 00:00:10.525
# chamado de superposição
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
a = "Sendo assim, os estados quânticos dos kiubites podem ser considerados como um vetor em um espaço vetorial complexo bidimensional, onde os estados kete 0 e kete 1, naturalmente ortogonais, formam a base do espaço vetorial, chamada de base computacional."


generate_audio(f"{a}", "6.mp3")
# Out:
# WEBVTT
#
# 00:00:00.100 --> 00:00:04.450
# Sendo assim os estados quânticos dos kiubites podem ser considerados
#
# 00:00:04.463 --> 00:00:08.488
# como um vetor em um espaço vetorial complexo bidimensional onde
#
# 00:00:08.500 --> 00:00:13.125
# os estados kete 0 e kete 1 naturalmente ortogonais formam a
#
# 00:00:13.137 --> 00:00:16.950
# base do espaço vetorial chamada de base computacional
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
a = "Uma das propriedades mais importantes de estados quânticos, é de que não é possível medir o estado phi de um kiubite sem alterá-lo. Isso nos diz que após realizar uma medida de um estado phi de um kiubite, o estado do kiubite será alterado para um dos estados da base computacional, kete 0 ou kete 1. A probabilidade de medir o estado kete 0 é de módulo de alpha ao quadrado, e a probabilidade de medir o estado kete 1 é de módulo de beta ao quadrado. Onde a soma dessas probabilidades tem que ser igual a 1."


generate_audio(f"{a}", "7.mp3")
# Out:
# WEBVTT
#
# 00:00:00.100 --> 00:00:03.962
# Uma das propriedades mais importantes de estados quânticos é de
#
# 00:00:03.975 --> 00:00:06.275
# que não é possível medir o estado phi de um
#
# 00:00:06.287 --> 00:00:10.025
# kiubite sem alterá-lo Isso nos diz que após realizar uma
#
# 00:00:10.037 --> 00:00:12.738
# medida de um estado phi de um kiubite o estado
#
# 00:00:12.750 --> 00:00:15.963
# do kiubite será alterado para um dos estados da base
#
# 00:00:15.975 --> 00:00:20.562
# computacional kete 0 ou kete 1 A probabilidade de medir o
#
# 00:00:20.575 --> 00:00:23.812
# estado kete 0 é de módulo de alpha ao quadrado e
#
# 00:00:23.825 --> 00:00:27.150
# a probabilidade de medir o estado kete 1 é de módulo
#
# 00:00:27.163 --> 00:00:30.950
# de beta ao quadrado Onde a soma dessas probabilidades tem
#
# 00:00:30.962 --> 00:00:31.950
# que ser igual a 1
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
a = "Sendo assim, o estado de um kiubite deve pertencer à circunferencia unitária no plano complexo, de modo a respeitar as probabilidades alpha ao quadrado ou probabilidade de obter 0 e beta ao quadrado ou probabilidade de obter 1."


generate_audio(f"{a}", "8.mp3")
# Out:
# WEBVTT
#
# 00:00:00.100 --> 00:00:03.350
# Sendo assim o estado de um kiubite deve pertencer à
#
# 00:00:03.362 --> 00:00:07.550
# circunferencia unitária no plano complexo de modo a respeitar as
#
# 00:00:07.562 --> 00:00:12.012
# probabilidades alpha ao quadrado ou probabilidade de obter 0 e beta
#
# 00:00:12.025 --> 00:00:14.550
# ao quadrado ou probabilidade de obter 1
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
